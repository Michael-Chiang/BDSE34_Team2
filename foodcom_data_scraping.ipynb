# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import requests
import os
import re
import pandas as pd
import glob

# %%
def extract_number(filename):
    # 获取文件名部分
    base_name = os.path.basename(filename)
    # 提取文件名中的数字部分
    number = ''.join(filter(str.isdigit, base_name))
    return int(number) if number else float('inf')
# 指定包含 CSV 文件的目录路径
folder_path = 'foodcom_url'

# 使用 glob 库获取目录下所有 CSV 文件的路径
csv_files = sorted(glob.glob(os.path.join(folder_path, '*.csv')), key=extract_number)

# 读取所有 CSV 文件并将它们存储在一个列表中
dataframes = [pd.read_csv(file) for file in csv_files]

# 将所有 DataFrame 合并成一个 DataFrame
combined_df = pd.concat(dataframes, ignore_index=True).iloc[1:, :]
recipe_url_list = combined_df.values.tolist()
recipe_url_list = [recipe_url[0] for recipe_url in recipe_url_list]

# %%
save_dir = r"C:\Users\USER\OneDrive\final_group_project\foodcom_images"
# save_dir = r"C:\Users\student\OneDrive\final_group_project\foodcom_images"
save_path = []
# 定義正則表達式模式
patterns = {
    "Calories": r"Calories:\s+([\d.]+)",
    "Calories from Fat": r"Calories from Fat\s+([\d.]+)\s+g",
    "Total Fat": r"Total Fat\s+([\d.]+)\s+g",
    "Saturated Fat": r"Saturated Fat\s+([\d.]+)\s+g",
    "Cholesterol": r"Cholesterol\s+([\d.]+)\s+mg",
    "Sodium": r"Sodium\s+([\d.]+)\s+mg",
    "Total Carbohydrate": r"Total Carbohydrate\s+([\d.]+)\s+g",
    "Dietary Fiber": r"Dietary Fiber\s+([\d.]+)\s+g",
    "Sugars": r"Sugars\s+([\d.]+)\s+g",
    "Protein": r"Protein\s+([\d.]+)\s+g",
}
# 定義包含非法字符的正則表達式模式
illegal_chars_pattern = r'[\/\\\?<>:\*\|"]'

column_names = ['Filename', 'Calories', 'Calories from Fat', 'Total Fat', 'Saturated Fat', 'Cholesterol', \
                'Sodium', 'Total Carbohydrate', 'Dietary Fiber', 'Sugars', 'Protein']
data_df = pd.DataFrame(columns=column_names)

# %%
# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知


# 初始化 WebDriver
service = Service(executable_path="./chromedriver.exe")  # 替換為 ChromeDriver 的路徑
# 使用 Chrome 的 WebDriver
# my_service = Service(executable_path="./chromedriver.exe")
driver = webdriver.Chrome(
    options = my_options,
    service = service
)
# driver.implicitly_wait(15)

# %%
for i, recipe_url in enumerate(recipe_url_list[:200]):
    print(f"i = {i}, recipe_url = {recipe_url}")
    try:
        driver.get(recipe_url)
        time.sleep(3)  # 等待頁面加載
    except:
        print('recipe_url not found')
    
    filename = recipe_url[:].split('/')[-1] + '.jpg'
    # filename = driver.find_element(By.CSS_SELECTOR, "div > h1").text
    # # 使用 re.sub() 函數去除非法字符
    # filename = re.sub(illegal_chars_pattern, '', filename)
    # filename = filename.replace(" ", "_")
    print(f"filename = {filename}")

    try:
        image = driver.find_element(By.CSS_SELECTOR, 'img[style*="--aspect-ratio: 5/4;"]')  # 替換為正確的CSS選擇器
        image_url = image.get_attribute('src')
        print('Image URL:', image_url)
    except:
        print('Image not found')
    # 爬取食譜圖片

    # 下载图片
    response = requests.get(image_url)
    time.sleep(2)  # 等待頁面加載
    if response.status_code == 200:
        # 拼接保存路径
        save_path = os.path.join(save_dir, filename)
        # 保存图片到指定路径
        with open(save_path, 'wb') as f:
            f.write(response.content)
        print('img save to:', save_path)
    else:
        print('download img failed!')

    # press "Nutrition information" button
    nutrition_section_btn = driver.find_element(By.CSS_SELECTOR, 'button.facts__nutrition')  # 替換為正確的CSS選擇器
    nutrition_section_btn.click()

    # concat nutrition data to a string
    nutrition = ''
    nutrition_facts = driver.find_elements(By.CSS_SELECTOR, 'p.recipe-nutrition__item.svelte-epeb0m')
    for nutrition_fact in nutrition_facts:
        nutrition += nutrition_fact.text

    # 提取數值
    nutrition_info = [filename]
    for key, pattern in patterns.items():
        match = re.search(pattern, nutrition)
        if match:
            nutrition_info.append(float(match.group(1)))


    # append to nutrition data
    data_df.loc[len(data_df.index)] = nutrition_info

# save nutrition data to foodcom_data.csv
file_path = 'foodcom_images/foodcom_data.csv'
if not os.path.exists(file_path):
    data_df.to_csv(file_path, index=False)
else:
    data_df.to_csv(file_path, mode='a', index=False, header=False)
# Out:
# i = 0, recipe_url = https://www.food.com/recipe/barbs-gumbo-82288
# filename = barbs-gumbo-82288.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/82/28/8/cB14froTlmpDfRF49wmQ_gumbo%2520SITE-3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\barbs-gumbo-82288.jpg
# i = 1, recipe_url = https://www.food.com/recipe/bourbon-chicken-45809
# filename = bourbon-chicken-45809.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/45/80/9/MwuCd6HpQ5mDvn4OLRkA_0S9A9886.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\bourbon-chicken-45809.jpg
# i = 2, recipe_url = https://www.food.com/recipe/best-banana-bread-2886
# filename = best-banana-bread-2886.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/28/86/wBZxNua1T8yfDwbfo9Fz_0S9A9315.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\best-banana-bread-2886.jpg
# i = 3, recipe_url = https://www.food.com/recipe/to-die-for-crock-pot-roast-27208
# filename = to-die-for-crock-pot-roast-27208.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/27/20/8/LoLdAamfR02FY46yIy0B_crockpot-roast-4637.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\to-die-for-crock-pot-roast-27208.jpg
# i = 4, recipe_url = https://www.food.com/recipe/crock-pot-chicken-with-black-beans-cream-cheese-89204
# filename = crock-pot-chicken-with-black-beans-cream-cheese-89204.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/89/20/4/uxMwt1VGQ5m2ePyzwHWy_salsa-chicken-black-beans-2312.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\crock-pot-chicken-with-black-beans-cream-cheese-89204.jpg
# i = 5, recipe_url = https://www.food.com/recipe/creamy-cajun-chicken-pasta-39087
# filename = creamy-cajun-chicken-pasta-39087.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/39/08/7/VPeSMiYHRce4BWsyj7Nl_0S9A5582.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\creamy-cajun-chicken-pasta-39087.jpg
# i = 6, recipe_url = https://www.food.com/recipe/oatmeal-raisin-cookies-35813
# filename = oatmeal-raisin-cookies-35813.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/35/81/3/KU3JVxMDRriISEG3KdPy_0S9A9740.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\oatmeal-raisin-cookies-35813.jpg
# i = 7, recipe_url = https://www.food.com/recipe/best-ever-banana-cake-with-cream-cheese-frosting-67256
# filename = best-ever-banana-cake-with-cream-cheese-frosting-67256.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/67/25/6/ErcPhaBVS2OMnh07iiZf_banana-cake-with-cream-cheese-frosting-08.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\best-ever-banana-cake-with-cream-cheese-frosting-67256.jpg
# i = 8, recipe_url = https://www.food.com/recipe/yes-virginia-there-is-a-great-meatloaf-54257
# filename = yes-virginia-there-is-a-great-meatloaf-54257.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/54/25/7/1O1KC1wTKTskFlseYbws_0S9A6432.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\yes-virginia-there-is-a-great-meatloaf-54257.jpg
# i = 9, recipe_url = https://www.food.com/recipe/jo-mamas-world-famous-spaghetti-22782
# filename = jo-mamas-world-famous-spaghetti-22782.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/22/78/2/xy39o2sOTtudkgyDgZtv_spaghettisauce.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\jo-mamas-world-famous-spaghetti-22782.jpg
# i = 10, recipe_url = https://www.food.com/recipe/quot-whatever-floats-your-boat-quot-brownies-32204
# filename = quot-whatever-floats-your-boat-quot-brownies-32204.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/32/20/4/yX79JawzR3CHcGEGWh4I_0S9A5678.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\quot-whatever-floats-your-boat-quot-brownies-32204.jpg
# i = 11, recipe_url = https://www.food.com/recipe/ice-cubes-420398
# filename = ice-cubes-420398.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/42/03/98/picFV7OMs.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\ice-cubes-420398.jpg
# i = 12, recipe_url = https://www.food.com/recipe/pancakes-25690
# filename = pancakes-25690.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/25/69/0/picwslJ1c.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\pancakes-25690.jpg
# i = 13, recipe_url = https://www.food.com/recipe/beer-bread-73440
# filename = beer-bread-73440.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/73/44/0/A5wJAHiTGmrCubWmruoJ_0S9A2475.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\beer-bread-73440.jpg
# i = 14, recipe_url = https://www.food.com/recipe/kittencals-italian-melt-in-your-mouth-meatballs-69173
# filename = kittencals-italian-melt-in-your-mouth-meatballs-69173.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/69/17/3/f6nXT71TDaqam1w0sxuw_untitled-4262.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\kittencals-italian-melt-in-your-mouth-meatballs-69173.jpg
# i = 15, recipe_url = https://www.food.com/recipe/japanese-mums-chicken-68955
# filename = japanese-mums-chicken-68955.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/68/95/5/TnfcMfTwRVulI0xETm67_jchicken.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\japanese-mums-chicken-68955.jpg
# i = 16, recipe_url = https://www.food.com/recipe/creamy-burrito-casserole-33919
# filename = creamy-burrito-casserole-33919.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/33/91/9/eK932J5iRgKgQGjoAwMG_IMG_7036.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\creamy-burrito-casserole-33919.jpg
# i = 17, recipe_url = https://www.food.com/recipe/kittencals-moist-cheddar-garlic-oven-fried-chicken-breast-82102
# filename = kittencals-moist-cheddar-garlic-oven-fried-chicken-breast-82102.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/82/10/2/C3VxQIrFT1aDvMUykuA0_0S9A5607.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\kittencals-moist-cheddar-garlic-oven-fried-chicken-breast-82102.jpg
# i = 18, recipe_url = https://www.food.com/recipe/banana-banana-bread-25885
# filename = banana-banana-bread-25885.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/25/88/5/CRAukFk1Tf2xpDPtcOUB_0S9A1642.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\banana-banana-bread-25885.jpg
# i = 19, recipe_url = https://www.food.com/recipe/scalloped-potatoes-85629
# filename = scalloped-potatoes-85629.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/85/62/9/ALhTKCBsRHu6JnlXk8Qy_0S9A3426.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\scalloped-potatoes-85629.jpg
# i = 20, recipe_url = https://www.food.com/recipe/the-best-easy-beef-and-broccoli-stir-fry-99476
# filename = the-best-easy-beef-and-broccoli-stir-fry-99476.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/99/47/6/01z114QRWGncDabUUJod_0S9A5937.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\the-best-easy-beef-and-broccoli-stir-fry-99476.jpg
# i = 21, recipe_url = https://www.food.com/recipe/oven-fried-chicken-chimichangas-28148
# filename = oven-fried-chicken-chimichangas-28148.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/28/14/8/Ew9disSrTws0LLBWlpbQ_0S9A2424.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\oven-fried-chicken-chimichangas-28148.jpg
# i = 22, recipe_url = https://www.food.com/recipe/fannie-farmers-classic-baked-macaroni-cheese-135350
# filename = fannie-farmers-classic-baked-macaroni-cheese-135350.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/13/53/50/kMWg48mzQPqqHG00V5xT_1maccheese3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\fannie-farmers-classic-baked-macaroni-cheese-135350.jpg
# i = 23, recipe_url = https://www.food.com/recipe/simply-sour-cream-chicken-enchiladas-129926
# filename = simply-sour-cream-chicken-enchiladas-129926.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/12/99/26/fqaHKUZ5Qxe1JYEmj5sO_DSC02592.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\simply-sour-cream-chicken-enchiladas-129926.jpg
# i = 24, recipe_url = https://www.food.com/recipe/southern-buttermilk-biscuits-26110
# filename = southern-buttermilk-biscuits-26110.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/26/11/0/DmfK6TnxRUqzDwn2P4tb_batch23-7025.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\southern-buttermilk-biscuits-26110.jpg
# i = 25, recipe_url = https://www.food.com/recipe/soft-snickerdoodle-cookies-97496
# filename = soft-snickerdoodle-cookies-97496.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/97/49/6/N4RvBXiYSwuoHfj9wkJw_snickerdoodles-3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\soft-snickerdoodle-cookies-97496.jpg
# i = 26, recipe_url = https://www.food.com/recipe/paneras-cream-cheese-potato-soup-150863
# filename = paneras-cream-cheese-potato-soup-150863.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/15/08/63/zbOVaZ4MSAO81CYiVyZK_panera-baked-potato-cream-cheese-soup-3763.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\paneras-cream-cheese-potato-soup-150863.jpg
# i = 27, recipe_url = https://www.food.com/recipe/crock-pot-whole-chicken-33671
# filename = crock-pot-whole-chicken-33671.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/33/67/1/PpaBfRQmQDG7MToNnJu1_crockpot-whole-chicken-2256.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\crock-pot-whole-chicken-33671.jpg
# i = 28, recipe_url = https://www.food.com/recipe/delicious-chicken-pot-pie-10744
# filename = delicious-chicken-pot-pie-10744.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/10/74/4/AyB790BXQZSOoGfb5I8o_0S9A2765.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\delicious-chicken-pot-pie-10744.jpg
# i = 29, recipe_url = https://www.food.com/recipe/my-familys-favorite-sloppy-joes-pizza-joes-63689
# filename = my-familys-favorite-sloppy-joes-pizza-joes-63689.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/63/68/9/omzyoNv4TbqKCfkCXhax_sloppy%2520joe.jpg3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\my-familys-favorite-sloppy-joes-pizza-joes-63689.jpg
# i = 30, recipe_url = https://www.food.com/recipe/beths-melt-in-your-mouth-barbecue-ribs-oven-107786
# filename = beths-melt-in-your-mouth-barbecue-ribs-oven-107786.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/10/77/86/mr5ViaW4TBmhRU3uCtLB_0S9A8585.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\beths-melt-in-your-mouth-barbecue-ribs-oven-107786.jpg
# i = 31, recipe_url = https://www.food.com/recipe/petes-scratch-pancakes-5170
# filename = petes-scratch-pancakes-5170.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/51/70/nwoyHKPSAWTjjpcSL5gs_scratch-pancakes-7.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\petes-scratch-pancakes-5170.jpg
# i = 32, recipe_url = https://www.food.com/recipe/olive-garden-copycat-zuppa-toscana-38298
# filename = olive-garden-copycat-zuppa-toscana-38298.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/38/29/8/Z8MMxtVfQfCLy4zZJtZU_0S9A7184.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\olive-garden-copycat-zuppa-toscana-38298.jpg
# i = 33, recipe_url = https://www.food.com/recipe/crock-pot-cream-cheese-chicken-12458
# filename = crock-pot-cream-cheese-chicken-12458.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/12/45/8/VVn84YRTQmeNB0cBrcr4_0S9A3316.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\crock-pot-cream-cheese-chicken-12458.jpg
# i = 34, recipe_url = https://www.food.com/recipe/chicken-lazone-65768
# filename = chicken-lazone-65768.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/65/76/8/SftRJCP5ROe4xjaH6fRW_chicken-lazone-3813.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\chicken-lazone-65768.jpg
# i = 35, recipe_url = https://www.food.com/recipe/fudge-crinkles-a-great-4-ingredient-cake-mix-cookie-32614
# filename = fudge-crinkles-a-great-4-ingredient-cake-mix-cookie-32614.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/32/61/4/y8M4HL6NRWywP92X5Hky_0S9A1122.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\fudge-crinkles-a-great-4-ingredient-cake-mix-cookie-32614.jpg
# i = 36, recipe_url = https://www.food.com/recipe/pork-chops-yum-yum-95222
# filename = pork-chops-yum-yum-95222.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/95/22/2/lBDNCe9SnyGbB0iOyEVG_pork-chops-yum-yum-5930.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\pork-chops-yum-yum-95222.jpg
# i = 37, recipe_url = https://www.food.com/recipe/the-best-brownies-54225
# filename = the-best-brownies-54225.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/54/22/5/DGMPaRDnQzSOR3Kw5Jo6_BB%25204%2520final%2520-%2520best%2520brownies.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\the-best-brownies-54225.jpg
# i = 38, recipe_url = https://www.food.com/recipe/mexican-rice-117892
# filename = mexican-rice-117892.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/11/78/92/WlojZNwSSKqBLqEXjpWA_THE%2520FOOD%2520GAYS%2520-%2520MEXICAN%2520RICE-2.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\mexican-rice-117892.jpg
# i = 39, recipe_url = https://www.food.com/recipe/sour-cream-banana-bread-9351
# filename = sour-cream-banana-bread-9351.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/93/51/uAo0F9diTyqexMQJctEk_batch23-6608.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\sour-cream-banana-bread-9351.jpg
# i = 40, recipe_url = https://www.food.com/recipe/pulled-pork-crock-pot-131018
# filename = pulled-pork-crock-pot-131018.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/13/10/18/I2XUukFxTtWOikkk0abF_pulled%20pork%20SITE-3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\pulled-pork-crock-pot-131018.jpg
# i = 41, recipe_url = https://www.food.com/recipe/kittencals-5-minute-cinnamon-flop-brunch-cake-77397
# filename = kittencals-5-minute-cinnamon-flop-brunch-cake-77397.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/77/39/7/kxel5d6sQouVmnsDO9BZ_brunch%2520flop%2520cake%2520SITE-3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\kittencals-5-minute-cinnamon-flop-brunch-cake-77397.jpg
# i = 42, recipe_url = https://www.food.com/recipe/greek-potatoes-oven-roasted-and-delicious-87782
# filename = greek-potatoes-oven-roasted-and-delicious-87782.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/87/78/2/GvYCvLdzQb2AyElhhEou_batch23-7123.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\greek-potatoes-oven-roasted-and-delicious-87782.jpg
# i = 43, recipe_url = https://www.food.com/recipe/chicken-tortilla-soup-ii-4627
# filename = chicken-tortilla-soup-ii-4627.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/46/27/qqOoqDQTPGvIJlhmncLL_chicken%20tortilla%20soup-3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\chicken-tortilla-soup-ii-4627.jpg
# i = 44, recipe_url = https://www.food.com/recipe/better-than-olive-garden-alfredo-sauce-141983
# filename = better-than-olive-garden-alfredo-sauce-141983.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/14/19/83/tu3zov4TR1WQpkvyKBKM_OGAS%25204%2520final%2520-%2520better%2520than%2520olive%2520garden%2520alfredo%2520sauce.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\better-than-olive-garden-alfredo-sauce-141983.jpg
# i = 45, recipe_url = https://www.food.com/recipe/the-best-chili-you-will-ever-taste-73166
# filename = the-best-chili-you-will-ever-taste-73166.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/73/16/6/jQ7zEif7QAuWHpy0nwFs_best%2520chili%2520SITE-3.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\the-best-chili-you-will-ever-taste-73166.jpg
# i = 46, recipe_url = https://www.food.com/recipe/reeses-squares-5-ingredients-no-bake-reeses-29679
# filename = reeses-squares-5-ingredients-no-bake-reeses-29679.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/29/67/9/J1stgzFRTqkYn2HpK1Kn_RS%25207%2520-%2520final_4.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\reeses-squares-5-ingredients-no-bake-reeses-29679.jpg
# i = 47, recipe_url = https://www.food.com/recipe/absolute-best-ever-lasagna-28768
# filename = absolute-best-ever-lasagna-28768.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/28/76/8/SyAcnUdwTHGQfekagLBj_ABEL%25203%2520-%2520final_1.png
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\absolute-best-ever-lasagna-28768.jpg
# i = 48, recipe_url = https://www.food.com/recipe/spinach-artichoke-dip-1209
# filename = spinach-artichoke-dip-1209.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/12/09/Q1us4KDT27bPD0yngmgv_0S9A2706.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\spinach-artichoke-dip-1209.jpg
# i = 49, recipe_url = https://www.food.com/recipe/melt-in-your-mouth-chicken-breasts-37336
# filename = melt-in-your-mouth-chicken-breasts-37336.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/37/33/6/1KevDZYLSSuYcrmrXpeu_0S9A1389.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\melt-in-your-mouth-chicken-breasts-37336.jpg
# i = 50, recipe_url = https://www.food.com/recipe/panera-broccoli-cheese-soup-150384
# filename = panera-broccoli-cheese-soup-150384.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/15/03/84/CsokZG1NTuqBSLb2lOcf_copycat-panera-cheesy-broccoli-soup-3266.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\panera-broccoli-cheese-soup-150384.jpg
# i = 51, recipe_url = https://www.food.com/recipe/peach-cobbler-31901
# filename = peach-cobbler-31901.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/31/90/1/wCkYSmRxQPi0CVYVb7RC_DSC02030.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\peach-cobbler-31901.jpg
# i = 52, recipe_url = https://www.food.com/recipe/the-sweetest-blueberry-muffins-50719
# filename = the-sweetest-blueberry-muffins-50719.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/50/71/9/XgiEMwG3QZyGYIkRwUzM_0S9A3646.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\the-sweetest-blueberry-muffins-50719.jpg
# i = 53, recipe_url = https://www.food.com/recipe/easy-stove-top-macaroni-cheese-60350
# filename = easy-stove-top-macaroni-cheese-60350.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/60/35/0/JWYBZJMdS2uM1SwQaI7Q_stovetop-macaroni-cheese-8831.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\easy-stove-top-macaroni-cheese-60350.jpg
# i = 54, recipe_url = https://www.food.com/recipe/the-most-wonderful-gingerbread-cookies-80156
# filename = the-most-wonderful-gingerbread-cookies-80156.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/80/15/6/hVNf9A7ZQ96mqTPHHSif_DSC_0046.JPG
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\the-most-wonderful-gingerbread-cookies-80156.jpg
# i = 55, recipe_url = https://www.food.com/recipe/crumb-topped-banana-muffins-43509
# filename = crumb-topped-banana-muffins-43509.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/43/50/9/1eW291d3QG2kKUHfRgon_crumblemuffins2%2520(1%2520of%25201).jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\crumb-topped-banana-muffins-43509.jpg
# i = 56, recipe_url = https://www.food.com/recipe/chinese-fried-rice-38748
# filename = chinese-fried-rice-38748.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/38/74/8/TCTWMVk2RVmMC8K039qk_0S9A2600.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\chinese-fried-rice-38748.jpg
# i = 57, recipe_url = https://www.food.com/recipe/wonderful-salsa-9272
# filename = wonderful-salsa-9272.jpg
# Image URL: https://img.sndimg.com/food/image/upload/f_auto,c_thumb,q_55,w_744,ar_5:4/v1/img/recipes/92/72/57kV2MbdSregy8TZfkHj_batch23-6580.jpg
# img save to: C:\Users\USER\OneDrive\final_group_project\foodcom_images\wonderful-salsa-9272.jpg
# i = 58, recipe_url = https://www.food.com/recipe/dark-chocolate-cake-2496

# %%
# 關閉 WebDriver
driver.quit()
